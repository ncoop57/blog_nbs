# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# ---------------------------------------------------------------------------
# AuthorizationError                        Traceback (most recent call last)
# <ipython-input-1-93f8cbc33ddf> in <module>()
#       1 from google.colab import auth
# ----> 2 auth.authenticate_user()
#       3 print('Authenticated')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/auth.py in authenticate_user(clear_output)
#     149     context_manager = _output.temporary if clear_output else _noop
#     150     with context_manager():
# --> 151       _gcloud_login()
#     152     _install_adc()
#     153     colab_tpu_addr = _os.environ.get('COLAB_TPU_ADDR', '')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/auth.py in _gcloud_login()
#      99     _os.remove(name)
#     100   if gcloud_process.returncode:
# --> 101     raise _errors.AuthorizationError('Error fetching credentials')
#     102
#     103
#
# AuthorizationError: Error fetching credentials

# %%
# %load_ext google.colab.data_table

# %%
import pandas as pd

project_id = 'stackoverflow-qa'
sample_count = 2000
df = pd.io.gbq.read_gbq('''
SELECT q.title, q.body AS `q_body`, a.body AS `a_body`, a.score, (case when q.accepted_answer_id = a.id then 1 else 0 end) AS `acc_a`
FROM `bigquery-public-data.stackoverflow.posts_answers` AS a
INNER JOIN `bigquery-public-data.stackoverflow.posts_questions` AS q ON a.parent_id = q.id
WHERE a.score > 0
LIMIT 100
''', project_id = project_id, dialect= 'standard')

df.head()
# Out:
#                                                title  ... acc_a
# 0                            List Mutation on Python  ...     0
# 1  Simple example for why Same Origin Policy is n...  ...     1
# 2                      Adding an image to the JFrame  ...     1
# 3  How to parse nested json arrays in a single ob...  ...     0
# 4                            List Mutation on Python  ...     1
#
# [5 rows x 5 columns]

# %% [markdown]
# # SCRATCH WORK

# %%
import pandas as pd

project_id = 'stackoverflow-qa'
sample_count = 2000
df = pd.io.gbq.read_gbq('''
SELECT *
FROM `bigquery-public-data.stackoverflow.posts_answers` AS question
LIMIT 100
''', project_id = project_id, dialect= 'standard')

df.head()
# Out:
#         id title  ...  tags view_count
# 0  8862561  None  ...  None       None
# 1  8862576  None  ...  None       None
# 2  8862577  None  ...  None       None
# 3  8862591  None  ...  None       None
# 4  8862600  None  ...  None       None
#
# [5 rows x 20 columns]

# %%
import pandas as pd

project_id = 'stackoverflow-qa'
sample_count = 2000
df = pd.io.gbq.read_gbq('''
SELECT *
FROM `bigquery-public-data.stackoverflow.posts_questions` AS question
INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS answers
LIMIT 100
''', project_id = project_id, dialect= 'standard')

df.head()
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas_gbq/gbq.py in run_query(self, query, **kwargs)
#     529         try:
# --> 530             rows_iter = query_reply.result()
#     531         except self.http_error as ex:
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, page_size, retry, max_results)
#    2973         try:
# -> 2974             super(QueryJob, self).result(timeout=timeout)
#    2975
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     767         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 768         return super(_AsyncJob, self).result(timeout=timeout)
#     769
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/future/polling.py in result(self, timeout)
#     126             # Pylint doesn't recognize that this is valid in this case.
# --> 127             raise self._exception
#     128
#
# BadRequest: 400 INNER JOIN must have an immediately following ON or USING clause at [4:1]
#
# (job ID: 1daa4509-d356-484c-80b0-12e9ae1aeae3)
#
#                        -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:SELECT *
#    3:FROM `bigquery-public-data.stackoverflow.posts_questions` AS question
#    4:INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS answers
#    5:LIMIT 100
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#
# During handling of the above exception, another exception occurred:
#
# GenericGBQException                       Traceback (most recent call last)
# <ipython-input-9-7b160fffe015> in <module>()
#       8 INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS answers
#       9 LIMIT 100
# ---> 10 ''', project_id = project_id, dialect= 'standard')
#      11
#      12 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, private_key, verbose, progress_bar_type)
#     184         configuration=configuration,
#     185         credentials=credentials,
# --> 186         **kwargs,
#     187     )
#     188
#
# /usr/local/lib/python3.6/dist-packages/pandas_gbq/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, verbose, private_key)
#     970     )
#     971
# --> 972     final_df = connector.run_query(query, configuration=configuration)
#     973
#     974     # Reindex the DataFrame on the provided column
#
# /usr/local/lib/python3.6/dist-packages/pandas_gbq/gbq.py in run_query(self, query, **kwargs)
#     530             rows_iter = query_reply.result()
#     531         except self.http_error as ex:
# --> 532             self.process_http_error(ex)
#     533
#     534         schema_fields = [field.to_api_repr() for field in rows_iter.schema]
#
# /usr/local/lib/python3.6/dist-packages/pandas_gbq/gbq.py in process_http_error(ex)
#     435         # <https://cloud.google.com/bigquery/troubleshooting-errors>`__
#     436
# --> 437         raise GenericGBQException("Reason: {0}".format(ex))
#     438
#     439     def run_query(self, query, **kwargs):
#
# GenericGBQException: Reason: 400 INNER JOIN must have an immediately following ON or USING clause at [4:1]
#
# (job ID: 1daa4509-d356-484c-80b0-12e9ae1aeae3)
#
#                        -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:SELECT *
#    3:FROM `bigquery-public-data.stackoverflow.posts_questions` AS question
#    4:INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS answers
#    5:LIMIT 100
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |

# %%
# SELECT
#   questions.title,
#   questions.Id as 'q_id',
#   questions.body as 'q_body',
#   questions.score as 'q_score',
#   (case 
#     when questions.AcceptedAnswerId = answers.Id
#     then 1
#     else 0 end) as 'acc_a',
#   answers.Id as 'a_id',
#   answers.body as 'a_body',
#   answers.score as 'a_score'
# FROM Posts answers
# INNER JOIN Posts questions ON answers.parentid = questions.id
# WHERE questions.title like '%how%'
# AND questions.tags like '%java%'
# AND questions.tags not like '%javascript%'
# AND answers.score > 0
# order by questions.id asc
# OFFSET 50000 ROWS
# FETCH FIRST 50000 ROWS ONLY;
